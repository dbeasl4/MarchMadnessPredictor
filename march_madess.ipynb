# %%
import os
folders = ['csvFiles']
for folder in folders:
    if not os.path.exists(folder):
        os.makedirs(folder)
        print(f"Created {folder}")

# %%
# !scrapy runspider kenpom_spider.py -o csvFiles/kenpom_data.csv
# Out:
# 2026-03-17 14:41:37 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2026-03-17 14:41:37 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.13.9, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.12.8 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:48:34) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 24.2.1 (OpenSSL 3.0.18 30 Sep 2025), cryptography 43.0.0, Platform Windows-11-10.0.26200-SP0
# 2026-03-17 14:41:37 [scrapy.addons] INFO: Enabled addons:
# []
# 2026-03-17 14:41:37 [py.warnings] WARNING: C:\Users\beasl\anaconda3\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# ...

# %%
scrapy runspider torvik_spider.py
# Out:
#   Cell In[39], line 1
#     scrapy runspider torvik_spider.py
#            ^
# SyntaxError: invalid syntax
